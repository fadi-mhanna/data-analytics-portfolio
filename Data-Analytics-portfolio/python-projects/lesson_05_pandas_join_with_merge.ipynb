# %%
employees ={
    'EmployeeID':['101', '102', '103'],
    'Name':['Fadi', 'Sean', 'John']
}

# %%
import pandas as pd

# %%
print(employees)
# Out:
# {'EmployeeID': ['101', '102', '103'], 'Name': ['Fadi', 'Sean', 'John']}

# %%
sales = {
    'EmployeeID': ['101', '102', '101', '103'],
    'Revenue': [500, 700, 600, 400]
}

# %%
df_employees = pd.DataFrame(employees)

# %%
df_employees
# Out:
#   EmployeeID  Name
# 0        101  Fadi
# 1        102  Sean
# 2        103  John

# %%
df_sales = pd.DataFrame(sales)

# %%
df_sales
# Out:
#   EmployeeID  Revenue
# 0        101      500
# 1        102      700
# 2        101      600
# 3        103      400

# %%
df_employees.merge(df_sales, on = 'EmployeeID')
# Out:
#   EmployeeID  Name  Revenue
# 0        101  Fadi      500
# 1        101  Fadi      600
# 2        102  Sean      700
# 3        103  John      400

# %%
employees = {
    'EmployeeID': ['101', '102', '103', '104'],
    'Name': ['Fadi', 'Sean', 'John', 'Sara']
}
df_employees = pd.DataFrame(employees)

# %%
df_employees.merge(df_sales, on = 'EmployeeID')
# Out:
#   EmployeeID  Name  Revenue
# 0        101  Fadi      500
# 1        101  Fadi      600
# 2        102  Sean      700
# 3        103  John      400

# %%
df_employees.merge(df_sales, on = 'EmployeeID', how = 'left')
# Out:
#   EmployeeID  Name  Revenue
# 0        101  Fadi    500.0
# 1        101  Fadi    600.0
# 2        102  Sean    700.0
# 3        103  John    400.0
# 4        104  Sara      NaN

# %%
df_sales.merge(df_employees, on='EmployeeID', how='left')
# Out:
#   EmployeeID  Revenue  Name
# 0        101      500  Fadi
# 1        102      700  Sean
# 2        101      600  Fadi
# 3        103      400  John

# %%
result = df_employees.merge(df_sales, on='EmployeeID', how='left')
result
# Out:
#   EmployeeID  Name  Revenue
# 0        101  Fadi    500.0
# 1        101  Fadi    600.0
# 2        102  Sean    700.0
# 3        103  John    400.0
# 4        104  Sara      NaN
