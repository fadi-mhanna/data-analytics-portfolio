# %%
import pandas as pd

# %%
reviews = pd.read_csv('C:\\Users\\fadim\\vs code\\Data-Analytics-portfolio\\datasets\\winemag-data-130k-v2.csv', index_col = 0)

# %%
reviews.head

# %%
reviews.head(10)

# %%
reviews.columns

# %%
reviews.shape

# %%
reviews.info()

# %%
reviews.describe()

# %%
reviews['country']

# %%
reviews[['country', 'price']]

# %%
reviews.iloc[0]

# %%
reviews.iloc[0:11]

# %%
reviews['country'][0]

# %%
reviews.iloc[10:21]

# %%
reviews.iloc[0, 0]

# %%
reviews.iloc[[1,2,3]]

# %%
reviews.iloc[:, [0,1,2]]

# %%
reviews.iloc[0:5, 0:3]

# %%
reviews.iloc[-5:]

# %%
reviews['country'].iloc[0:10]

# %%
reviews.iloc[50:61, 1:4]

# %%
reviews.iloc[:, -1]

# %%
reviews.iloc[-10:, 0:3]

# %%
reviews.iloc[100:111, -2:]

# %%
reviews.loc[reviews.country == 'Italy']

# %%
reviews.loc[reviews.points >= 95]

# %%
reviews.loc[(reviews.country == 'France') & (reviews.points >= 95)]
