# %%
import pandas as pd

# %%
sales = { 'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'],
           'Revenue': [1200, 1500, 1800, 2200, 3500] }

# %%
df= pd.DataFrame(sales)
df
# Out:
#          Day  Revenue
# 0     Monday     1200
# 1    Tuesday     1500
# 2  Wednesday     1800
# 3   Thursday     2200
# 4     Friday     3500

# %%
total_revenue = df['Revenue'].sum()
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 10200

# %%
maximum_revenue = df['Revenue'].max()
print("Maximum Revenue:", maximum_revenue)
# Out:
# Maximum Revenue: 3500

# %%
the_mean_revenue = df['Revenue'].mean()
print("Mean Revenue:", the_mean_revenue)
# Out:
# Mean Revenue: 2040.0

# %%
df['Day'][df['Revenue'] == maximum_revenue]
# Out:
# 4    Friday
# Name: Day, dtype: str

# %%
df.loc[df["Revenue"].idxmax()]
# Out:
# Day        Friday
# Revenue      3500
# Name: 4, dtype: object

# %%
df.loc[df['Day'].idxmax()]
# Out:
# Day        Wednesday
# Revenue         1800
# Name: 2, dtype: object

# %%
df[df['Revenue']>2000]
# Out:
#         Day  Revenue
# 3  Thursday     2200
# 4    Friday     3500

# %%
df.loc[df['Revenue']>1500]
# Out:
#          Day  Revenue
# 2  Wednesday     1800
# 3   Thursday     2200
# 4     Friday     3500
