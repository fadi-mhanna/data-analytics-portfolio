# %%
import pandas as pd

# %%
sales = { 'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'],
           'Revenue': [1200, 1500, 1800, 2200, 3500] }

# %%
df= pd.DataFrame(sales)
df
# Out:
#          Day  Revenue
# 0     Monday     1200
# 1    Tuesday     1500
# 2  Wednesday     1800
# 3   Thursday     2200
# 4     Friday     3500

# %%
total_revenue = df['Revenue'].sum()
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 10200

# %%
maximum_revenue = df['Revenue'].max()
print("Maximum Revenue:", maximum_revenue)
# Out:
# Maximum Revenue: 3500

# %%
the_mean_revenue = df['Revenue'].mean()
print("Mean Revenue:", the_mean_revenue)
# Out:
# Mean Revenue: 2040.0

# %%
df['Day'][df['Revenue'] == maximum_revenue]
# Out:
# 4    Friday
# Name: Day, dtype: str

# %%
df.loc[df["Revenue"].idxmax()]
# Out:
# Day        Friday
# Revenue      3500
# Name: 4, dtype: object

# %%
df.loc[df['Day'].idxmax()]
# Out:
# Day        Wednesday
# Revenue         1800
# Name: 2, dtype: object

# %%
df[df['Revenue']>2000]
# Out:
#         Day  Revenue
# 3  Thursday     2200
# 4    Friday     3500

# %%
df.loc[df['Revenue']>1500]
# Out:
#          Day  Revenue
# 2  Wednesday     1800
# 3   Thursday     2200
# 4     Friday     3500

# %%
df['Revenue']
# Out:
# 0    1200
# 1    1500
# 2    1800
# 3    2200
# 4    3500
# Name: Revenue, dtype: int64

# %%
weekly_revenue = df['Revenue'].sum()
print('Our weekly revenue is: ', weekly_revenue)
# Out:
# Our weekly revenue is:  10200

# %%
df['Day'][df['Revenue'].idxmax()]
# Out:
# 'Friday'

# %%
df['Day'][df['Revenue']>2000]
# Out:
# 3    Thursday
# 4      Friday
# Name: Day, dtype: str

# %%
average_prformance = df['Revenue'].mean()
print('The Average Performance is :', average_prformance)
# Out:
# The Average Performance is : 2040.0

# %%
df.sort_values(by='Revenue', ascending=False)
# Out:
#          Day  Revenue
# 4     Friday     3500
# 3   Thursday     2200
# 2  Wednesday     1800
# 1    Tuesday     1500
# 0     Monday     1200

# %%
df.sort_values(by= 'Revenue', ascending = False).head(2)
# Out:
#         Day  Revenue
# 4    Friday     3500
# 3  Thursday     2200

# %%
df['Category'] = ['low', 'low', 'medium', 'high', 'very high']
df
# Out:
#          Day  Revenue   Category
# 0     Monday     1200        low
# 1    Tuesday     1500        low
# 2  Wednesday     1800     medium
# 3   Thursday     2200       high
# 4     Friday     3500  very high

# %%
df[['Day', 'Category']]
# Out:
#          Day   Category
# 0     Monday        low
# 1    Tuesday        low
# 2  Wednesday     medium
# 3   Thursday       high
# 4     Friday  very high

# %%
df['Day'][df['Category']== 'high']
# Out:
# 3    Thursday
# Name: Day, dtype: str

# %%
df[(df['Revenue']>1500) & (df['Category']== 'medium')]
# Out:
#          Day  Revenue Category
# 2  Wednesday     1800   medium

# %%
df[(df['Revenue'] > 2000) |(df['Category'] == 'medium')]
# Out:
#          Day  Revenue   Category
# 2  Wednesday     1800     medium
# 3   Thursday     2200       high
# 4     Friday     3500  very high
